# %% [markdown]
# #### Importing Basic Libraries

# %%
import pandas as pd
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing the dataset

# %%
df =pd.read_csv(r'C:\Users\DELL\Downloads\baseball.csv')
df.head() ### Checking the dataset
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
## Checking the dataset shape 
df.shape
# Out:
# (30, 17)

# %%
### Checking the null values in dataset
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# ### There are no null values in the the dataset

# %%
### Checking the datatype of the dataset 
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# ## EDA

# %%
### Importing the basic visualization matrix
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
### Plotting scatterplot to check the trend between features and target
sns.scatterplot(df['R'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - Runs Scored (R) has good relation with the Win(W)

# %%
### Plotting scatterplot to check the trend between features and target
sns.scatterplot(df['AB'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - At Bat (R) has good relation with the Win(W)

# %%
sns.scatterplot(df['H'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - Hit(H) has good relation with the Win(W)

# %%
sns.scatterplot(df['2B'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - Double(2B) has good relation with the Win (W)

# %%
sns.scatterplot(df['3B'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - Triplet(3B) has mixed relation with the Win (W)

# %%
sns.scatterplot(df['HR'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - Home Run(3B) has good rise up relation with the Win (W)

# %%
sns.scatterplot(df['BB'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - Base on ball (BB) has good rise up relation with the Win (W)

# %%
sns.scatterplot(df['SO'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - (SO) has good relation with the Win (W)

# %%
sns.scatterplot(df['SB'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - SB has Mixed relation with the Win (W)

# %%
sns.scatterplot(df['RA'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - RA has Reverse relation with the Win (W). We can also consider this and check it in colinearity section.

# %%
sns.scatterplot(df['ER'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - ER has Reverse relation with the Win (W). We can also consider this and check it in colinearity section.

# %%
sns.scatterplot(df['ERA'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - ERA has Reverse relation with the Win (W). We can also consider this and check it in colinearity section.

# %%
sns.scatterplot(df['CG'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - CG has good relation with the Win (W)

# %%
sns.scatterplot(df['SHO'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - SHO has good relation with the Win (W).

# %%
sns.scatterplot(df['SV'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - SV has good trend with the Win (W).

# %%
sns.scatterplot(df['E'],df['W'])
plt.show()

# %% [markdown]
# ### Conclusion - E has good trend with the Win (W).

# %% [markdown]
# ## Conclusion
#
# #### All the feature has good realtion with target, only three features has reverse relation with target. I can move forward with all features now.

# %% [markdown]
# ## Checking the multicolinearity by using Heatmap.

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(), annot=True, fmt='.2f', linewidths=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### There are 3 featues has multicollinearity with each other, which is RA,ER and ERA and has multicollinearity above 99%  . Other features are seems good and has no multicollinearity with each other.
# ### The target has maximum trend with - SV(67%)
# ### The target has minimum trend with - H(0%)
# ### Every feature has not strong trend with target. So, I will drop two feature ER and ERA.

# %%
df.drop(columns=['ER', 'ERA'], inplace=True)

# %% [markdown]
# ### Checking the disctribution of all the features and target

# %%
df.plot(kind='density', subplots=True, figsize=(20,15), layout = (6,12), fontsize =2, sharex=False, legend= False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### All the feature has normal distribution.

# %% [markdown]
# ## Checking the Stats of the dataset using Heatmap

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.describe(), annot=True, fmt='.2f', linewidths=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# ### All the stats looks good. we do not need to do and modification on that.

# %% [markdown]
# ### Checking the skewness

# %%
x=df.drop(columns='W')
y=df['W']
x.skew().sort_values()
# Out:
# 2B    -0.230650
# SO    -0.156065
# RA     0.045734
# 3B     0.129502
# BB     0.158498
# AB     0.183437
# SB     0.479893
# HR     0.516441
# SHO    0.565790
# SV     0.657524
# H      0.670254
# CG     0.736845
# E      0.890132
# R      1.200786
# dtype: float64

# %% [markdown]
# ### There only few features who has skewness rest feature dose not has any skewness. As keeping the standard thresold +/- 0.5 and removing the skewness with power transform.

# %%
from sklearn.preprocessing import power_transform ### Importing the Power Transform
x_new = power_transform(x)
x=pd.DataFrame(x_new, columns=x.columns)

# %%
x.skew().sort_values()
# Out:
# 3B    -0.072933
# CG    -0.059785
# 2B    -0.035315
# SB    -0.010455
# RA    -0.008082
# BB    -0.007760
# HR    -0.000065
# R      0.000000
# AB     0.000000
# H      0.000000
# SV     0.000836
# SHO    0.006560
# SO     0.041170
# E      0.063909
# dtype: float64

# %% [markdown]
# ### Now the skewness is removed. Now I can move forward and check the stats of the model.

# %% [markdown]
# ## Checking the outliers

# %%
plt.figure(figsize=(15,13))
pn = 1
for column in x:
    if pn <= 18:
        ax = plt.subplot(6,3, pn)
        sns.boxplot(x[column])
        plt.xlabel(column)
    pn+=1
plt.tight_layout()

# %% [markdown]
# ### SHO feature has only 2 outliers and E has only one outliers, Which can be accept because this can be expception. So, I am not going remove these outliers.

# %% [markdown]
# ## Model Building

# %%
### Spliting the feature and target to proceed the model building
x=df.drop(columns='W')
y=df['W']

### Importing some preprocesing library for model 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
### Scaling then feature with standard scaler 
sc = StandardScaler()
x_scaled= sc.fit_transform(x)

# %%
#### Splitting the dataset into traing data and testing data
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y, test_size=0.20, random_state=25)
print(len(x_train), len(y_train), len(x_test), len(y_test))
# Out:
# 24 24 6 6

# %%
### Importing the libraries for model building.
from sklearn.metrics import r2_score, plot_roc_curve, mean_absolute_error, mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
### Importing the LinearRegression and checking the r2 score, cross validation and errors
lr= LinearRegression()
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
r2_lr =r2_score(y_test,pred_lr)
scr = cross_val_score(lr, x,y, cv=5)
Corss_lr = scr.mean()
mae_lr = mean_absolute_error(y_test,pred_lr)
mse_lr = mean_squared_error(y_test,pred_lr)
rmse_lr = np.sqrt(mse_lr)
print("\t\t\t LinearRegression Model Accuracy and r2 score, cross validation and errors",  '\n\nR2 score for LinearRegression model', r2_lr*100, '\n Cross Validation score ', Corss_lr*100, '\nMean_absolute_error', mae_lr,"\nMean_squared_error", mse_lr, '\nRoot mean_squared_error', rmse_lr )
# Out:
# 			 LinearRegression Model Accuracy and r2 score, cross validation and errors
#
# R2 score for LinearRegression model 73.45063851397822
#  Cross Validation score  34.03737484572956
# Mean_absolute_error 4.1279207019459
# Mean_squared_error 19.77189948445123
# Root mean_squared_error 4.4465604105253345

# %%
### Importing the DecisionTreeRegressor and checking the score and r2 score, cross validation and errors
DTR= DecisionTreeRegressor()
DTR.fit(x_train,y_train)
pred_DTR=DTR.predict(x_test)
r2_DTR =r2_score(y_test,pred_DTR)
scr = cross_val_score(DTR, x,y, cv=5)
Corss_DTR = scr.mean()
mae_DTR = mean_absolute_error(y_test,pred_DTR)
mse_DTR = mean_squared_error(y_test,pred_DTR)
rmse_DTR = np.sqrt(mse_DTR)

print("\t\t\t DecisionTreeRegressor Model Accuracy and r2 score, cross validation and errors",  '\n\nR2 score for DecisionTreeRegressor model', r2_DTR*100, '\n Cross Validation score -', Corss_DTR*100, '\nMean_absolute_error', mae_DTR,"\nMean_squared_error", mse_DTR, '\nRoot mean_squared_error', rmse_DTR )
# Out:
# 			 DecisionTreeRegressor Model Accuracy and r2 score, cross validation and errors
#
# R2 score for DecisionTreeRegressor model 0.8578888474449875
#  Cross Validation score - -218.9937543802167
# Mean_absolute_error 8.166666666666666
# Mean_squared_error 73.83333333333333
# Root mean_squared_error 8.59263250310016

# %%
### Importing the RandomForestRegressor and checking the score and r2 score
RFR= RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
r2_RFR =r2_score(y_test,pred_RFR)
scr = cross_val_score(RFR, x,y, cv=5)
Corss_RFR = scr.mean()
mae_RFR = mean_absolute_error(y_test,pred_RFR)
mse_RFR = mean_squared_error(y_test,pred_RFR)
rmse_RFR = np.sqrt(mse_RFR)

print("\t\t\t RandomForestRegressor Model Accuracy and r2 score, cross validation and errors",  '\n\nR2 score for RandomForestRegressor model', r2_RFR*100, '\n Cross Validation score -', Corss_RFR*100, '\nMean_absolute_error', mae_RFR,"\nMean_squared_error", mse_RFR, '\nRoot mean_squared_error', rmse_RFR )
# Out:
# 			 RandomForestRegressor Model Accuracy and r2 score, cross validation and errors
#
# R2 score for RandomForestRegressor model 46.4927116747483
#  Cross Validation score - -61.57471445448021
# Mean_absolute_error 4.753333333333333
# Mean_squared_error 39.84806666666662
# Root mean_squared_error 6.3125325081671155

# %%
### Importing the KNeighborsRegressor and checking the score and r2 score
KNN= KNeighborsRegressor()
KNN.fit(x_train,y_train)
pred_KNN=KNN.predict(x_test)
r2_KNN =r2_score(y_test,pred_KNN)
scr = cross_val_score(KNN, x,y, cv=5)
Corss_KNN = scr.mean()
mae_KNN = mean_absolute_error(y_test,pred_KNN)
mse_KNN = mean_squared_error(y_test,pred_KNN)
rmse_KNN = np.sqrt(mse_KNN)

print("\t\t\t KNeighborsRegressor Model Accuracy and r2 score, cross validation and errors",  '\nR2 score for KNeighborsRegressor model', r2_KNN*100, '\n Cross Validation score -', Corss_KNN*100, '\nMean_absolute_error', mae_KNN,"\nMean_squared_error", mse_KNN, '\nRoot mean_squared_error', rmse_KNN)
# Out:
# 			 KNeighborsRegressor Model Accuracy and r2 score, cross validation and errors
# R2 score for KNeighborsRegressor model 36.16411786646773
#  Cross Validation score - -70.16381770213901
# Mean_absolute_error 4.899999999999999
# Mean_squared_error 47.54000000000001
# Root mean_squared_error 6.89492567037528

# %%
### Importing the SupportVectorRegressor and checking the score and r2 score
svr= SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
r2_svr=r2_score(y_test,pred_svr)
scr = cross_val_score(svr, x,y, cv=5)
Corss_svr = scr.mean()
mae_svr = mean_absolute_error(y_test,pred_svr)
mse_svr = mean_squared_error(y_test,pred_svr)
rmse_svr = np.sqrt(mse_svr)
print("\t\t\t SupportVectorRegressor Model Accuracy and r2 score, cross validation and errors",  '\n\nR2 score for SupportVectorRegressor model', r2_svr*100, '\n Cross Validation score -', Corss_svr*100, '\nMean_absolute_error', mae_svr,"\nMean_squared_error", mse_svr, '\nRoot mean_squared_error', rmse_svr)
# Out:
# 			 SupportVectorRegressor Model Accuracy and r2 score, cross validation and errors
#
# R2 score for SupportVectorRegressor model -57.451640569736554
#  Cross Validation score - -45.87929546657314
# Mean_absolute_error 8.392941872630233
# Mean_squared_error 117.25773565762881
# Root mean_squared_error 10.828561107443075

# %% [markdown]
# ### I performed 5 model prediction Model Accuracy and r2 score, cross validation and errors are mentioned below -
#
# #### Accuracy score and cross validation score for LinearRegression model 73.45063851397822  and cross validation score is 34.03737484572956
# #### Accuracy score cross validation score for DecisionTreeRegressor model 0.8578888474449875  and cross validation score is 218.9937543802167
# #### Accuracy score cross validation score for RandomForestRegressor model 46.4927116747483  and cross validation score is -61.57471445448021
# #### Accuracy score cross validation score for KNeighborsRegressor model 36.16411786646773  and cross validation score is -70.16381770213901
# #### Accuracy score cross validation score  for SupportVectorRegressor model -57.451640569736554   and cross validation score is -45.87929546657314
#
# ### From the above, I conclude that I will go forward with LinearRegression because the accuracy is normal but the diffrence betweem R2_score and Cross validation is very less compariosn to other model and aslo has very low difference in Cross validation score but we can do better hyperparameter tuning with RandomForestRegressor. May the Accuracy will increase.

# %%
#### importing the GridSearchCV for hyperparameter tuning.
from sklearn.model_selection import GridSearchCV
RFR = RandomForestRegressor()
para = {'n_estimators':range(1,4),
       'criterion':["mse", "mae"],
        'max_depth':range(2,8),
    'min_samples_split':range(2,10),
    'min_samples_leaf':range(1,8)}

# %%
gridsearch= GridSearchCV(estimator=RFR, param_grid=para, cv=5, n_jobs=-1)
gridsearch.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': range(2, 8),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 10),
#                          'n_estimators': range(1, 4)})

# %%
gridsearch.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 6,
#  'min_samples_leaf': 1,
#  'min_samples_split': 6,
#  'n_estimators': 3}

# %%
RFR = RandomForestRegressor(criterion='mae',max_depth= 6,min_samples_leaf=9,min_samples_split= 6,n_estimators= 5)

# %%
### Importing the RandomForestRegressor and checking the score and r2 score
RFRg= RandomForestRegressor()
RFRg.fit(x_train,y_train)
pred_RFRg=RFRg.predict(x_test)
r2_RFRg =r2_score(y_test,pred_RFRg)
scr = cross_val_score(RFRg, x,y, cv=5)
Corss_RFRg = scr.mean()
mae_RFRg = mean_absolute_error(y_test,pred_RFRg)
mse_RFRg = mean_squared_error(y_test,pred_RFRg)
rmse_RFRg = np.sqrt(mse_RFRg)

print("\t\t\t RandomForestRegressor Model Accuracy and r2 score, cross validation and errors",  '\n\nR2 score for RandomForestRegressor model', r2_RFRg*100, '\n Cross Validation score ', Corss_RFRg*100, '\nMean_absolute_error', mae_RFRg,"\nMean_squared_error", mse_RFRg, '\nRoot mean_squared_error', rmse_RFRg )
# Out:
# 			 RandomForestRegressor Model Accuracy and r2 score, cross validation and errors
#
# R2 score for RandomForestRegressor model 54.96696754942189
#  Cross Validation score  -73.06006091166924
# Mean_absolute_error 4.356666666666665
# Mean_squared_error 33.53709999999998
# Root mean_squared_error 5.7911225164038775

# %% [markdown]
# ## Conclusion
#
# ### I tried very much to increase the R2 Score and decrease the difference between r2 score and cross validaion but did not get better result. So, I am going to save this model with RandomForestRegressor, RandomForestRegressor has 73.45063851397822  and cross validation score is 34.03737484572956 which is best from other models.

# %% [markdown]
# ## Saving the model

# %%
import joblib
joblib.dump(lr, 'Baseball_case_study')
# Out:
# ['Baseball_case_study']
