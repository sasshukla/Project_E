# %% [markdown]
# #### Importing Basic Libraries

# %%
import pandas as pd
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing the dataset

# %%
df =pd.read_csv(r'C:\Users\DELL\Downloads\WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.tail() ### Checking the dataset
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
## Checking the dataset shape 
df.shape
# Out:
# (1470, 35)

# %%
### Checking the null values in dataset
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### There are no null values in the the dataset

# %%
### Checking the datatype of the dataset 
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# ### There are more features which is categorial value and has datatype is object.

# %% [markdown]
# ## Now I will change the categorical data into Intergers as the model will understand only integers

# %%
### Importing label encoder
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder() ## Initialzing the labeEncoder
col = ['Attrition','BusinessTravel','Department','EducationField', 'Gender','JobRole','MaritalStatus','Over18','OverTime']
df[col] = df[col].apply(le.fit_transform) 
df.head() ### Checking the dataset that the model
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
### Checking the datatype again to check the datatype that it will changed to integer or not
df.dtypes
# Out:
# Age                         int64
# Attrition                   int32
# BusinessTravel              int32
# DailyRate                   int64
# Department                  int32
# DistanceFromHome            int64
# Education                   int64
# EducationField              int32
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int32
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int32
# JobSatisfaction             int64
# MaritalStatus               int32
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# Over18                      int32
# OverTime                    int32
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# ...

# %% [markdown]
# ### Now all the columns are in same datatype.

# %% [markdown]
# ## EDA

# %%
### Importing the basic visualization matrix
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
print(df['Attrition'].value_counts())
sns.countplot(x='Attrition', data=df)
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# #### Attrition has imbalanced values, I will deal with this at the time of model building.

# %%
print(df['BusinessTravel'].value_counts())
sns.countplot(x='BusinessTravel', data=df)
# Out:
# 2    1043
# 1     277
# 0     150
# Name: BusinessTravel, dtype: int64
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# #### Business Travel as also has imbalanced values, I will deal with this at the time of model building.

# %%
print(df['Department'].value_counts())
sns.countplot(x='Department', data=df)
# Out:
# 1    961
# 2    446
# 0     63
# Name: Department, dtype: int64
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# #### Department has some balanced values compared to the others but not normally balanced, I will deal with this at the time of model building.

# %%
print(df['Education'].value_counts())
sns.countplot(x='Education', data=df)
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# #### Education has balanced values compared to the others.

# %%
print(df['EducationField'].value_counts())
sns.countplot(x='EducationField', data=df)
# Out:
# 1    606
# 3    464
# 2    159
# 5    132
# 4     82
# 0     27
# Name: EducationField, dtype: int64
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# #### Education has balanced values.

# %%
print(df['EmployeeCount'].value_counts())
sns.countplot(x='EmployeeCount', data=df)
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64
# <AxesSubplot:xlabel='EmployeeCount', ylabel='count'>

# %% [markdown]
# ### Employee Count has only one value. So I am going to drop this column from the dataset because it will not going to help in model predication.

# %%
df.drop(columns='EmployeeCount', inplace=True) ### Dropper the column EmployeeCount

# %%
print(df['EmployeeNumber'].value_counts())
sns.countplot(x='EmployeeNumber', data=df)
# Out:
# 2048    1
# 1368    1
# 1364    1
# 1363    1
# 1362    1
#        ..
# 648     1
# 647     1
# 645     1
# 644     1
# 2046    1
# Name: EmployeeNumber, Length: 1470, dtype: int64
# <AxesSubplot:xlabel='EmployeeNumber', ylabel='count'>

# %% [markdown]
# ### EmployeeNumber dose not has any unique number. It will not going to give any contribute anything in the model building. So, I will drop this column.

# %%
df.drop(columns='EmployeeNumber', inplace=True) ### Dropper the column EmployeeNumber

# %%
print(df['EnvironmentSatisfaction'].value_counts())
sns.countplot(x='EnvironmentSatisfaction', data=df)
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %% [markdown]
# #### Environment Satisfaction has good distribution of the values. It shows good for model building.

# %%
print(df['JobInvolvement'].value_counts())
sns.countplot(x='JobInvolvement', data=df)
# Out:
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %% [markdown]
# #### Job Involvement has normal distribution of the values. No, need to change anything.

# %%
print(df['JobLevel'].value_counts())
sns.countplot(x='JobLevel', data=df)
# Out:
# 1    543
# 2    534
# 3    218
# 4    106
# 5     69
# Name: JobLevel, dtype: int64
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %% [markdown]
# #### JobLevel has normal distribution of the values. No, need to change anything.

# %%
print(df['JobRole'].value_counts())
sns.countplot(x='JobRole', data=df)
# Out:
# 7    326
# 6    292
# 2    259
# 4    145
# 0    131
# 3    102
# 8     83
# 5     80
# 1     52
# Name: JobRole, dtype: int64
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %%
print(df['JobSatisfaction'].value_counts())
sns.countplot(x='JobSatisfaction', data=df)
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %% [markdown]
# #### Job Involvement has normal distribution of the values. No, need to change anything.

# %%
print(df['MonthlyRate'].value_counts())
sns.countplot(x='MonthlyRate', data=df)
# Out:
# 4223     3
# 9150     3
# 9096     2
# 13008    2
# 12858    2
#         ..
# 17071    1
# 23213    1
# 3835     1
# 25258    1
# 12287    1
# Name: MonthlyRate, Length: 1427, dtype: int64
# <AxesSubplot:xlabel='MonthlyRate', ylabel='count'>

# %% [markdown]
# #### Monthly Rate has normal distribution of the values. No, need to change anything.

# %%
print(df['NumCompaniesWorked'].value_counts())
sns.countplot(x='NumCompaniesWorked', data=df)
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='count'>

# %% [markdown]
# #### NumCompaniesWorked has normal distribution of the values. No, need to change anything.

# %%
print(df['Over18'].value_counts())
sns.countplot(x='Over18', data=df)
# Out:
# 0    1470
# Name: Over18, dtype: int64
# <AxesSubplot:xlabel='Over18', ylabel='count'>

# %% [markdown]
# ### Over18 has only one value. So I am going to drop this column from the dataset because it will not going to help in model predication.

# %%
df.drop(columns='Over18', inplace=True) ### Dropping the Over18 column

# %%
print(df['OverTime'].value_counts())
sns.countplot(x='OverTime', data=df)
# Out:
# 0    1054
# 1     416
# Name: OverTime, dtype: int64
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %% [markdown]
# ### OverTime has not balanced values. I will deal with this at the time of model building

# %%
print(df['PercentSalaryHike'].value_counts())
sns.countplot(x='PercentSalaryHike', data=df)
# Out:
# 11    210
# 13    209
# 14    201
# 12    198
# 15    101
# 18     89
# 17     82
# 16     78
# 19     76
# 22     56
# 20     55
# 21     48
# 23     28
# 24     21
# 25     18
# Name: PercentSalaryHike, dtype: int64
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='count'>

# %% [markdown]
# #### PercentSalaryHike has normal distribution of the values. No, need to change anything.

# %%
print(df['PerformanceRating'].value_counts())
sns.countplot(x='PerformanceRating', data=df)
# Out:
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64
# <AxesSubplot:xlabel='PerformanceRating', ylabel='count'>

# %% [markdown]
# ### OverTime has not balanced values. I will deal with this at the time of model building

# %%
print(df['RelationshipSatisfaction'].value_counts())
sns.countplot(x='RelationshipSatisfaction', data=df)
# Out:
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='count'>

# %% [markdown]
# #### RelationshipSatisfaction has normal distribution of the values. No, need to change anything.

# %%
print(df['StandardHours'].value_counts())
sns.countplot(x='StandardHours', data=df)
# Out:
# 80    1470
# Name: StandardHours, dtype: int64
# <AxesSubplot:xlabel='StandardHours', ylabel='count'>

# %% [markdown]
# ### StandardHours has only one value. So I am going to drop this column from the dataset because it will not going to help in model predication.

# %%
df.drop(columns='StandardHours', inplace=True) ## Dropped the StandardHours column

# %%
print(df['StockOptionLevel'].value_counts())
sns.countplot(x='StockOptionLevel', data=df)
# Out:
# 0    631
# 1    596
# 2    158
# 3     85
# Name: StockOptionLevel, dtype: int64
# <AxesSubplot:xlabel='StockOptionLevel', ylabel='count'>

# %% [markdown]
# #### StockOptionLevel has normal distribution of the values. No, need to change anything.

# %%
print(df['TrainingTimesLastYear'].value_counts())
sns.countplot(x='TrainingTimesLastYear', data=df)
# Out:
# 2    547
# 3    491
# 4    123
# 5    119
# 1     71
# 6     65
# 0     54
# Name: TrainingTimesLastYear, dtype: int64
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='count'>

# %% [markdown]
# #### TrainingTimesLastYear has normal distribution of the values. No, need to change anything.

# %%
print(df['WorkLifeBalance'].value_counts())
sns.countplot(x='WorkLifeBalance', data=df)
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='count'>

# %% [markdown]
# #### WorkLifeBalance has normal distribution of the values. No, need to change anything.

# %%
### Conclusion 

####
# Out:
# 2     344
# 0     263
# 7     216
# 3     142
# 8     107
# 4      98
# 1      76
# 9      64
# 5      31
# 6      29
# 10     27
# 11     22
# 12     18
# 13     14
# 17      7
# 14      5
# 15      5
# 16      2
# Name: YearsWithCurrManager, dtype: int64
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='count'>

# %%
#### Plotting scatterplot to check the trend between features and target
x=df.drop(columns='Attrition')
y=df['Attrition']
plt.figure(figsize=(30,35))
pn=1
for column in x:
    if pn <= 40:
        plt.subplot(10,4, pn)
        sns.scatterplot(x[column],y)
        plt.xlabel(column)
    pn+=1
plt.show()

# %% [markdown]
# ### Conclusion
#
# #### All features has some relation with the target . So, I will consider all these features in model building.

# %% [markdown]
# ## Checking the multicolinearity by using Heatmap.

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(), annot=True, fmt='.2f', linewidths=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### More than 4 featues has multicollinearity with each other only Total working years has more than  (75% ) multicollinearity with Job Level and Mothly Income and year in currten role and years at company has more than 75% feature multicollinearity.
# ### The target has maximum trend with - Overtime(25%)
# ### The target has minimum trend with - Performance and Businesstravel(0%)
# ### Every feature has not strong trend with target expect Overtime. So, I will keep all feature for Model building.

# %% [markdown]
# ### Checking the disctribution of all the features and target

# %%
df.plot(kind='density', subplots=True, figsize=(20,15), layout = (6,12), fontsize =2, sharex=False, legend= False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Most of the Features has Skewness. So, I will check the skewness and fix it.

# %%
x=df.drop(columns='Attrition')
y=df['Attrition']
x.skew().sort_values()
# Out:
# BusinessTravel             -1.439006
# WorkLifeBalance            -0.552480
# JobInvolvement             -0.498419
# Gender                     -0.408665
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# EnvironmentSatisfaction    -0.321654
# RelationshipSatisfaction   -0.302828
# Education                  -0.289681
# MaritalStatus              -0.152175
# HourlyRate                 -0.032311
# DailyRate                  -0.003519
# MonthlyRate                 0.018578
# Department                  0.172231
# Age                         0.413286
# EducationField              0.550371
# TrainingTimesLastYear       0.553124
# PercentSalaryHike           0.821128
# YearsWithCurrManager        0.833451
# YearsInCurrentRole          0.917363
# DistanceFromHome            0.958118
# OverTime                    0.964489
# StockOptionLevel            0.968980
# JobLevel                    1.025401
# NumCompaniesWorked          1.026471
# ...

# %% [markdown]
# ### We can see there are more features has skewness which is lies between - 1.4 to 1.9. I will fix this with help of power transform

# %%
from sklearn.preprocessing import power_transform
x_new = power_transform(x)

x=pd.DataFrame(x_new, columns=x.columns)

# %%
x.skew().sort_values()
# Out:
# BusinessTravel             -0.925202
# Gender                     -0.408665
# Department                 -0.277228
# JobRole                    -0.086155
# TrainingTimesLastYear      -0.078892
# MaritalStatus              -0.065131
# JobSatisfaction            -0.048623
# EnvironmentSatisfaction    -0.043240
# DailyRate                  -0.042388
# RelationshipSatisfaction   -0.037733
# MonthlyRate                -0.036478
# TotalWorkingYears          -0.028299
# Age                        -0.027493
# NumCompaniesWorked         -0.026310
# HourlyRate                 -0.023643
# YearsWithCurrManager       -0.017367
# YearsInCurrentRole         -0.014873
# EducationField             -0.011150
# MonthlyIncome               0.000000
# PercentSalaryHike           0.011717
# DistanceFromHome            0.012294
# YearsAtCompany              0.017290
# Education                   0.022208
# StockOptionLevel            0.075143
# JobLevel                    0.077894
# ...

# %% [markdown]
# ### Now the skewness is removed. Now I can move forward and check the stats of the model

# %%
df.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.260544
# std       9.135373     0.367863        0.665455   403.509100     0.527792
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     1.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EnvironmentSatisfaction  \
# count       1470.000000  1470.000000     1470.000000              1470.000000
# mean           9.192517     2.912925        2.247619                 2.721769
# ...

# %% [markdown]
# ### Stats of the model is showing normal and most of the features is categorical value

# %% [markdown]
# ## Checking the outliers

# %%
plt.figure(figsize=(20,15))
pn = 1
for column in x:
    if pn <= 40:
        ax = plt.subplot(10,4, pn)
        sns.boxplot(x[column])
        plt.xlabel(column)
    pn+=1
plt.tight_layout()

# %% [markdown]
# ### Conclusion - Only 4 feature has outlires which is not that much that we can work on that, rest of all features has not any outlier. So,we do not need to remome these outliers because thes outliers wil be the obvious.

# %%
print(df['Attrition'].value_counts())
sns.countplot(x='Attrition', data=df)
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# ### I will deal with the imbalanced data and move forward to build model

# %%
from imblearn.over_sampling import RandomOverSampler
rus=  RandomOverSampler(random_state=37)
x_sam,y_sam=rus.fit_resample(x,y)
print(y_sam.value_counts())
ax=y_sam.value_counts().plot.pie()
# Out:
# 0    1233
# 1    1233
# Name: Attrition, dtype: int64

# %% [markdown]
# ### Now the data seems to be blananced and will use this feature and target in the model building. Now moving forward to the model building.

# %%
### Importing some preprocesing library for model 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
### Scaling then feature with standard scaler 
sc = StandardScaler()
x_scaled= sc.fit_transform(x_sam)

# %%
#### Splitting the dataset into traing data and testing data
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y_sam, test_size=0.20, random_state=25)
print(len(x_train), len(y_train), len(x_test), len(y_test))
# Out:
# 1972 1972 494 494

# %%
### Importing the model building libraries
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
### Importing the LogisticRegression and checking the score and cross validation score 
lr= LogisticRegression()
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
acc_lr =accuracy_score(y_test,pred_lr)
scr = cross_val_score(lr, x_scaled,y_sam, cv=5)
Clas_r = classification_report(y_test,pred_lr)
con = confusion_matrix(y_test,pred_lr)
Corss_lr = scr.mean()

print("\n LogisticRegression Model Accuracy ",  '\nAccuracy_score for LogisticRegression model', acc_lr*100, "\n Cross Validation score is ",Corss_lr*100, '\n Classification report is ', '\n' ,Clas_r, '\n Confusion Metrix is', '\n', con)
# Out:
#  LogisticRegression Model Accuracy
# Accuracy_score for LogisticRegression model 76.92307692307693
#  Cross Validation score is  77.81819973556922
#  Classification report is
#                precision    recall  f1-score   support
#
#            0       0.79      0.76      0.77       254
#            1       0.75      0.78      0.77       240
#
#     accuracy                           0.77       494
#    macro avg       0.77      0.77      0.77       494
# weighted avg       0.77      0.77      0.77       494
#
#  Confusion Metrix is
#  [[192  62]
#  [ 52 188]]

# %%
### Importing the RandomForestClassifier and  checking the score and cross validation score  
RFC= RandomForestClassifier()
RFC.fit(x_train,y_train)
pred_RFC=RFC.predict(x_test)
acc_RFC =accuracy_score(y_test,pred_RFC)
scr = cross_val_score(RFC, x_scaled,y_sam, cv=5)
Corss_rfc = scr.mean()
Clas_r = classification_report(y_test,pred_RFC)
con = confusion_matrix(y_test,pred_RFC)

print("\n RandomForestClassifier Model Accuracy",  '\n\nAccuracy_score for RandomForestClassifier model', acc_RFC*100, "\n Cross Validation score is ",Corss_rfc*100, '\n Classification report is ', '\n' ,Clas_r, '\n Confusion Metrix is', '\n', con)
# Out:
#  RandomForestClassifier Model Accuracy
#
# Accuracy_score for RandomForestClassifier model 98.98785425101214
#  Cross Validation score is  98.01307372034393
#  Classification report is
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       254
#            1       0.98      1.00      0.99       240
#
#     accuracy                           0.99       494
#    macro avg       0.99      0.99      0.99       494
# weighted avg       0.99      0.99      0.99       494
#
#  Confusion Metrix is
#  [[249   5]
#  [  0 240]]

# %%
### Importing the DecisionTreeClassifier and checking the score and cross validation score  
DTC= DecisionTreeClassifier()
DTC.fit(x_train,y_train)
pred_DTC=DTC.predict(x_test)
acc_DTC =accuracy_score(y_test,pred_DTC)
scr = cross_val_score(DTC, x_scaled,y_sam, cv=5)
Corss_dtc = scr.mean()
Clas_r = classification_report(y_test,pred_DTC)
con = confusion_matrix(y_test,pred_DTC)

print("\n DecisionTreeClassifier Model Accuracy",  '\n\nAccuracy_score for DecisionTreeClassifier model', acc_DTC*100, "\n Cross Validation score is ",Corss_dtc*100,'\n Classification report is ', '\n' ,Clas_r, '\n Confusion Metrix is', '\n', con)
# Out:
#  DecisionTreeClassifier Model Accuracy
#
# Accuracy_score for DecisionTreeClassifier model 92.91497975708502
#  Cross Validation score is  92.05221276001674
#  Classification report is
#                precision    recall  f1-score   support
#
#            0       1.00      0.86      0.93       254
#            1       0.87      1.00      0.93       240
#
#     accuracy                           0.93       494
#    macro avg       0.94      0.93      0.93       494
# weighted avg       0.94      0.93      0.93       494
#
#  Confusion Metrix is
#  [[219  35]
#  [  0 240]]

# %%
### Importing the KNeighborsClassifier and checking the score and cross validation score 
KNC= KNeighborsClassifier()
KNC.fit(x_train,y_train)
pred_KNC=KNC.predict(x_test)
acc_KNC =accuracy_score(y_test,pred_KNC)
scr = cross_val_score(KNC, x_scaled,y_sam, cv=5)
Corss = scr.mean()
Clas_r = classification_report(y_test,pred_KNC)
con = confusion_matrix(y_test,pred_KNC)
print("\n KNeighborsClassifier Model Accuracy",  '\n\nAccuracy_score for KNeighborsClassifier model', acc_KNC*100, "\n Cross Validation score is ",Corss*100,'\n Classification report is ', '\n' ,Clas_r, '\n Confusion Metrix is', '\n', con)
# Out:
#  KNeighborsClassifier Model Accuracy
#
# Accuracy_score for KNeighborsClassifier model 83.80566801619433
#  Cross Validation score is  83.57556396843255
#  Classification report is
#                precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83       254
#            1       0.80      0.89      0.84       240
#
#     accuracy                           0.84       494
#    macro avg       0.84      0.84      0.84       494
# weighted avg       0.84      0.84      0.84       494
#
#  Confusion Metrix is
#  [[200  54]
#  [ 26 214]]

# %%
### Importing the SVC and checking the score and cross validation score
svc= SVC()
svc.fit(x_train,y_train)
pred_svc=svc.predict(x_test)
acc_svc =accuracy_score(y_test,pred_svc)
scr = cross_val_score(svc, x_scaled,y_sam, cv=5)
Corss = scr.mean()
Clas_r = classification_report(y_test,pred_svc)
con = confusion_matrix(y_test,pred_svc)
print("\n SVC Model Accuracy",  '\n\nAccuracy_score for SVC model', acc_svc*100,"\n Cross Validation score is ",Corss*100,'\n Classification report is ', '\n' ,Clas_r, '\n Confusion Metrix is', '\n', con)
# Out:
#  SVC Model Accuracy
#
# Accuracy_score for SVC model 91.49797570850203
#  Cross Validation score is  91.07866404973268
#  Classification report is
#                precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       254
#            1       0.90      0.93      0.91       240
#
#     accuracy                           0.91       494
#    macro avg       0.91      0.92      0.91       494
# weighted avg       0.92      0.91      0.91       494
#
#  Confusion Metrix is
#  [[230  24]
#  [ 18 222]]

# %% [markdown]
# ### I performed 5 model prediction Accuracy score, those score are mentioned below -
#
# #### Accuracy score and cross validation score for LogisticRegression model 76.92307692307693 and cross validation score is 77.81819973556922
# #### Accuracy score cross validation score for RandomForestClassifier model 98.98785425101214 and cross validation score is 98.01307372034393
# #### Accuracy score cross validation score for DecisionTreeClassifier model 92.91497975708502 and cross validation score is 92.91497975708502
# #### Accuracy score cross validation score for KNeighborsClassifier model 83.80566801619433 and cross validation score is 83.57556396843255
# #### Accuracy score cross validation score  for SVC model 91.49797570850203 and cross validation score is 91.07866404973268
#
# ### From the above, I conclude that I will go forward with RandomForestClassifier because the accuracy is good compariosn to other model and aslo has very low difference in Cross validation score but we can do better hyperparameter tuning with RandomForestClassifier. May the Accuracy will increase.

# %%
from sklearn.model_selection import GridSearchCV
RFC= RandomForestClassifier()
para = {'n_estimators':range(15,30),
       'criterion':["entropy", "gini"],
        'max_depth':range(8,20),
    'min_samples_split':range(6,15),
    'min_samples_leaf':range(8,28)}

# %%
gridsearch= GridSearchCV(estimator=RFC, param_grid=para, cv=5, n_jobs=-1)
gridsearch.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': range(8, 20),
#                          'min_samples_leaf': range(8, 28),
#                          'min_samples_split': range(6, 15),
#                          'n_estimators': range(15, 30)})

# %%
gridsearch.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 12,
#  'min_samples_leaf': 8,
#  'min_samples_split': 9,
#  'n_estimators': 25}

# %%
RFC = RandomForestClassifier( criterion='entropy',max_depth=20,min_samples_leaf= 8,min_samples_split=15,n_estimators=30)

# %%
### Importing the KNeighborsClassifier and checking the score 
RFC.fit(x_train,y_train)
pred_RFC_grid=RFC.predict(x_test)
acc_RFC_grid =accuracy_score(y_test,pred_RFC_grid)
scr = cross_val_score(RFC, x_scaled,y_sam, cv=5)
Corss_rfc_grid = scr.mean()
Clas_r = classification_report(y_test,pred_RFC_grid)
con = confusion_matrix(y_test,pred_RFC_grid)

print("\n RandomForestClassifier Model Accuracy",  '\n\nAccuracy_score for RandomForestClassifier model', acc_RFC_grid*100, "\n Cross Validation score is ",Corss_rfc_grid*100, '\n Classification report is ', '\n' ,Clas_r, '\n Confusion Metrix is', '\n', con)
# Out:
#  RandomForestClassifier Model Accuracy
#
# Accuracy_score for RandomForestClassifier model 91.7004048582996
#  Cross Validation score is  91.4433650048041
#  Classification report is
#                precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92       254
#            1       0.90      0.94      0.92       240
#
#     accuracy                           0.92       494
#    macro avg       0.92      0.92      0.92       494
# weighted avg       0.92      0.92      0.92       494
#
#  Confusion Metrix is
#  [[228  26]
#  [ 15 225]]

# %% [markdown]
# ### Conclusion- I tried to change paratmeter multiple times but did not get better score. So, I will keep the model without hyperparameter tuning which scored 98%. Which is good.

# %% [markdown]
# ## Ploting ROC plot

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gridsearch.best_estimator_,x_test,y_test)
plt.show()

# %% [markdown]
# ### The ROC plot is also showing good score which is 97%.
#
# ### Conclusion - Mode is performing good.

# %% [markdown]
# ## Saving the model

# %%
import joblib
joblib.dump(KNC, 'HR-Employee-Attrition')
# Out:
# ['HR-Employee-Attrition']
